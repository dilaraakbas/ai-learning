# %% [markdown]
# ##Libraries Used and Why
# **pandas**: Used for loading, cleaning and manipulating tabular data (DataFrames). It allows easy handling of CSV files and data analysis operations.
# **numpy**: Used for numerical operations and handling missing values efficiently. It provides support for mathematical calculations used in data preprocessing.
# **matplotlib**: used for basic data visualization such as plots and histograms. It helps in understanding data distributions and relationships.
# **seaborn**: Built on top of matplotlib, it provides higher-level and more visually appealing statistical plots with less code.

# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset
# The dataset is loaded from a CSV file using pandas. CSV files are commonly used to store structured data, and pandas provides efficient tools to read and process them into DataFrame objects for analysis.

# %%
df = pd.read_csv("../data/sample_data.csv")
df
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Desktop/ai-learning/venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Notebook is working 🎉")
